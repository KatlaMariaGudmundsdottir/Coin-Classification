# %% [markdown]
# ### Import Datasets
# The dataset is loaded from the specified directory, and the toal number of classes is determined

# %%
import os
images_classes_path = './Extracted_Training_data'
image_classes_list = os.listdir(images_classes_path)
num_classes = len(image_classes_list)
print("total {} classes".format(num_classes))

import cv2 as cv

test_images_path = 'output'
images_dict = {}
image_name_list = os.listdir(test_images_path)
# print(image_name_list)
for image_folder in image_name_list:
    images_dict[image_folder] = []
    images_path = os.path.join(test_images_path, image_folder)
    for image in os.listdir(images_path):
        path_to_coin_image = os.path.join(images_path, image)
        images_dict[image_folder].append(path_to_coin_image)

print(len(images_dict["L0000000"]))
 
num_images = len(image_name_list)
print("total {} test images".format(num_images))
# Out:
# total 16 classes
# 7
# total 162 test images

# %% [markdown]
# ## Data Import and Preprocessing

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
import datetime
# !rm -rf ./logs/

# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
import matplotlib.image as mpimg
import numpy as np
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Prerpocessing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import random

# %%
datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range=20,
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0.3
)

crazy_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0.3
)


train_generator = datagen.flow_from_directory(
    images_classes_path,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    shuffle=True,
    subset="training"
)

val_generator = datagen.flow_from_directory(
    images_classes_path,
    target_size=(224, 224),
    batch_size=16,
    class_mode='categorical',
    shuffle=False, 
    subset='validation'
)


test_datagen=ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_images_path,
    target_size=(224, 224),
    shuffle=False,
    batch_size=1,
    class_mode='categorical'
)

filenames = test_generator.filenames
nb_samples= len(filenames)

x_batch, y_batch = next(train_generator)
print(f"Batch x_shape: {x_batch.shape}, Batch y_shape: {y_batch.shape}")

# Verify the data generators
train_batch = next(iter(train_generator))
val_batch = next(iter(val_generator))
print(train_batch[0].shape, train_batch[1].shape)
print(val_batch[0].shape, val_batch[1].shape)

print(f"Steps per epoch: {train_generator.samples // train_generator.batch_size}")
print(f"Validation steps: {val_generator.samples // val_generator.batch_size}")
# Out:
# Found 275 images belonging to 16 classes.
# Found 108 images belonging to 16 classes.
# Found 1068 images belonging to 162 classes.
# Batch x_shape: (16, 224, 224, 3), Batch y_shape: (16, 16)
# (16, 224, 224, 3) (16, 16)
# (16, 224, 224, 3) (16, 16)
# Steps per epoch: 17
# Validation steps: 6

# %% [markdown]
# ## Model configuration

# %%
import keras
from keras.layers import Input
from keras.models import Sequential, Model
from keras.optimizers import SGD, Adam

from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D, GlobalAveragePooling2D, BatchNormalization

# %% [markdown]
# ## Using VGG16

# %%
from keras.applications.vgg16 import VGG16

# %%
vgg16_base = VGG16(include_top=False, # Since we will create our own
                    weights='imagenet', 
                    input_shape=(224, 224, 3))
vgg16_base.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Fine-tuning the model

# %%
x = vgg16_base.output
x = Flatten()(x)
x = BatchNormalization()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(rate = .5)(x)
predictions = Dense(num_classes, activation='softmax')(x)

# %%
model = Model(inputs=vgg16_base.inputs, outputs=predictions)
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 25088)          │       100,352 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1024)           │    25,691,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │        16,400 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,522,576 (154.58 MB)
#  Trainable params: 40,472,400 (154.39 MB)
#  Non-trainable params: 50,176 (196.00 KB)

# %% [markdown]
# ### Transfer Learning

# %%
## Freezing in order to only train the last 7 layers
for layer in model.layers[:]:
    layer.trainable = True
for layer in model.layers[:-7]:
    layer.trainable = False
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.trainable)
model.summary()
# Out:
# 0 input_layer_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 False
# 16 block5_conv2 False
# 17 block5_conv3 True
# 18 block5_pool True
# 19 flatten_1 True
# 20 batch_normalization_1 True
# 21 dense_2 True
# 22 dropout_1 True
# 23 dense_3 True
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 25088)          │       100,352 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1024)           │    25,691,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │        16,400 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,522,576 (154.58 MB)
#  Trainable params: 28,117,520 (107.26 MB)
#  Non-trainable params: 12,405,056 (47.32 MB)

# %%
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer,
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ## Train the model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import TensorBoard

# %%
checkpoint = ModelCheckpoint('model.keras',
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)


my_callbacks = [checkpoint, tensorboard_callback, early_stopping_callback]

# %%
history = model.fit(train_generator,
          validation_data=val_generator,
          epochs=7,
          callbacks=my_callbacks)
print('Training done!')
# Out:
# Epoch 1/7
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.0914 - loss: 3.1550
# c:\Users\glanz\anaconda3\envs\iapr\lib\site-packages\keras\src\callbacks\model_checkpoint.py:206: UserWarning: Can save best model only with val_acc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 history = model.fit(train_generator,
#       2           validation_data=val_generator,
#       3           epochs=7,
#       4           callbacks=my_callbacks)
#       5 print('Training done!')
#
# File c:\Users\glanz\anaconda3\envs\iapr\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\glanz\anaconda3\envs\iapr\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py:196, in histogram(name, data, step, buckets, description)
#     192 @lazy_tensor_creator.LazyTensorCreator
#     193 def lazy_tensor():
#     194     return _buckets(data, buckets)
# --> 196 return tf.summary.write(
#     197     tag=tag,
#     198     tensor=lazy_tensor,
#     199     step=step,
#     200     metadata=summary_metadata,
#     201 )
#
# File c:\Users\glanz\anaconda3\envs\iapr\lib\site-packages\tensorboard\util\lazy_tensor_creator.py:66, in LazyTensorCreator.__call__(self)
#      64         elif self._tensor is None:
#      65             self._tensor = _CALL_IN_PROGRESS_SENTINEL
# ---> 66             self._tensor = self._tensor_callable()
#      67 return self._tensor
#
# File c:\Users\glanz\anaconda3\envs\iapr\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py:194, in histogram.<locals>.lazy_tensor()
#     192 @lazy_tensor_creator.LazyTensorCreator
#     193 def lazy_tensor():
# --> 194     return _buckets(data, buckets)
#
# File c:\Users\glanz\anaconda3\envs\iapr\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py:293, in _buckets(data, bucket_count)
#     287         return tf.transpose(a=tf.stack([edges, edges, bucket_counts]))
#     289     return tf.cond(
#     290         has_single_value, when_single_value, when_multiple_values
#     291     )
# --> 293 return tf.cond(is_empty, when_empty, when_nonempty)
#
# File c:\Users\glanz\anaconda3\envs\iapr\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py:289, in _buckets.<locals>.when_nonempty()
#     283     bucket_counts = tf.cast(
#     284         tf.concat([zeroes[:-1], [data_size]], 0)[:bucket_count],
#     285         dtype=tf.float64,
#     286     )
#     287     return tf.transpose(a=tf.stack([edges, edges, bucket_counts]))
# --> 289 return tf.cond(
#     290     has_single_value, when_single_value, when_multiple_values
#     291 )
#
# File c:\Users\glanz\anaconda3\envs\iapr\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py:258, in _buckets.<locals>.when_nonempty.<locals>.when_multiple_values()
#     254 clamped_indices = tf.minimum(bucket_indices, bucket_count - 1)
#     255 # Use float64 instead of float32 to avoid accumulating floating point error
#     256 # later in tf.reduce_sum when summing more than 2^24 individual `1.0` values.
#     257 # See https://github.com/tensorflow/tensorflow/issues/51419 for details.
# --> 258 one_hots = tf.one_hot(
#     259     clamped_indices, depth=bucket_count, dtype=tf.float64
#     260 )
#     261 bucket_counts = tf.cast(
#     262     tf.reduce_sum(input_tensor=one_hots, axis=0),
#     263     dtype=tf.float64,
#     264 )
#     265 edges = tf.linspace(min_, max_, bucket_count + 1)
#
# ResourceExhaustedError: {{function_node __wrapped__OneHot_device_/job:localhost/replica:0/task:0/device:CPU:0}} OOM when allocating tensor with shape[25690112,30] and type double on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu [Op:OneHot] name:

# %%
for layer in model.layers[:]:
    layer.trainable = True

# %%
# params = model.fit(train_generator, 
                                # validation_data=val_generator, 
                                # epochs=10,
                                # callbacks=my_callbacks)
# Out:
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9342 - loss: 0.2113
# c:\Users\katla\miniconda3\envs\iapr\lib\site-packages\keras\src\callbacks\model_checkpoint.py:206: UserWarning: Can save best model only with val_acc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.9350 - loss: 0.2093 - val_accuracy: 0.7963 - val_loss: 0.5550
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.9686 - loss: 0.1041 - val_accuracy: 0.7222 - val_loss: 0.9230
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 96s 5s/step - accuracy: 0.9621 - loss: 0.1580 - val_accuracy: 0.8148 - val_loss: 0.8216
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 95s 5s/step - accuracy: 0.9729 - loss: 0.0900 - val_accuracy: 0.8426 - val_loss: 0.6964
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.9859 - loss: 0.0699 - val_accuracy: 0.8519 - val_loss: 0.4926
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.9335 - loss: 0.2169 - val_accuracy: 0.7593 - val_loss: 0.7751
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 97s 5s/step - accuracy: 0.9648 - loss: 0.1912 - val_accuracy: 0.7963 - val_loss: 0.8380
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 97s 5s/step - accuracy: 0.9446 - loss: 0.2058 - val_accuracy: 0.8056 - val_loss: 0.8062
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 98s 5s/step - accuracy: 0.9668 - loss: 0.0891 - val_accuracy: 0.8519 - val_loss: 0.4910
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 93s 5s/step - accuracy: 0.9180 - loss: 0.2692 - val_accuracy: 0.8333 - val_loss: 0.7352

# %%
def plot_history(history):
    acc = np.array(history.history['accuracy'])
    val_acc = np.array(history.history['val_accuracy'])
    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])

    epochs = range(len(acc))

    plt.figure(figsize=(12, 8))

    # Plot training and validation accuracy
    plt.subplot(2, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot training and validation loss
    plt.subplot(2, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(2, 2, 3)
    plt.plot(epochs, acc, 'bo-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(2, 2, 4)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage:
# Assuming 'history' is the History object returned from model.fit
plot_history(history)
plot_history(params)

# %%
# %tensorboard --logdir logs/fit

# %%
import os
import time
import subprocess
from IPython.display import display, HTML

os.system('pkill -f "tensorboard"')
subprocess.Popen(["tensorboard", "--logdir", "logs/fit"])
time.sleep(5)
display(HTML(f'<a href="http://localhost:6006" target="_blank">Open TensorBoard</a>'))
# Out:
# <a href="http://localhost:6006" target="_blank">Open TensorBoard</a>

# %% [markdown]
# ## Test model on real images

# %%
def predict_images(path):
    # Load and display the image
    img = mpimg.imread(path)
    plt.imshow(img)
    plt.axis('off')  # Hide axis
    plt.show()

    # Preprocess the image
    image = Image.open(path)
    image = image.convert('RGB')
    image = image.resize((224, 224))
    image = np.array(image) / 255.0  # Normalize the image
    image = np.expand_dims(image, axis=0)  # Expand dimensions to fit model input

    # Predict the probabilities
    probabilities = model.predict(image)

    # Get class labels
    class_labels = {v: k for k, v in val_generator.class_indices.items()}

    # Prepare data for a nice display
    sorted_indices = np.argsort(probabilities[0])[::-1]
    results = [(class_labels[i], probabilities[0][i]) for i in sorted_indices]

    # Print sorted probabilities and their corresponding class labels
    print("Class".ljust(15), "Probability")
    print("-" * 30)
    for label, prob in results:
        print(f"{label.ljust(15)} : {prob:.4f}")

# Example usage
for key in images_dict:
    # List
    for coin_path in images_dict[key]:
        print(coin_path)
        predict_images(coin_path)

# predict_images('./Extracted_Training_Data/0.1CHF/L1010279_3.JPG')
# Out:
# output\L0000000\coin_0.jpg
# output\L0000000\coin_1.jpg
# output\L0000000\coin_2.jpg
# output\L0000000\coin_3.jpg
# output\L0000000\coin_4.jpg
# output\L0000000\coin_5.jpg
# output\L0000000\coin_6.jpg
# output\L0000001\coin_0.jpg
# output\L0000001\coin_1.jpg
# output\L0000001\coin_2.jpg
# output\L0000001\coin_3.jpg
# output\L0000001\coin_4.jpg
# output\L0000001\coin_5.jpg
# output\L0000001\coin_6.jpg
# output\L0000001\coin_7.jpg
# output\L0000001\coin_8.jpg
# output\L0000001\coin_9.jpg
# output\L0000002\coin_0.jpg
# output\L0000002\coin_1.jpg
# output\L0000002\coin_2.jpg
# output\L0000002\coin_3.jpg
# output\L0000002\coin_4.jpg
# output\L0000002\coin_5.jpg
# output\L0000003\coin_0.jpg
# output\L0000003\coin_1.jpg
# output\L0000003\coin_2.jpg
# output\L0000003\coin_3.jpg
# output\L0000003\coin_4.jpg
# output\L0000003\coin_5.jpg
# output\L0000003\coin_6.jpg
# output\L0000003\coin_7.jpg
# output\L0000003\coin_8.jpg
# output\L0000004\coin_0.jpg
# output\L0000004\coin_1.jpg
# output\L0000004\coin_2.jpg
# output\L0000004\coin_3.jpg
# output\L0000004\coin_4.jpg
# output\L0000004\coin_5.jpg
# output\L0000004\coin_6.jpg
# output\L0000005\coin_0.jpg
# output\L0000005\coin_1.jpg
# output\L0000005\coin_2.jpg
# output\L0000005\coin_3.jpg
# output\L0000005\coin_4.jpg
# output\L0000005\coin_5.jpg
# output\L0000005\coin_6.jpg
# output\L0000005\coin_7.jpg
# output\L0000005\coin_8.jpg
# output\L0000006\coin_0.jpg
# output\L0000006\coin_1.jpg
# output\L0000006\coin_2.jpg
# output\L0000006\coin_3.jpg
# output\L0000006\coin_4.jpg
# output\L0000006\coin_5.jpg
# output\L0000006\coin_6.jpg
# output\L0000006\coin_7.jpg
# output\L0000006\coin_8.jpg
# output\L0000006\coin_9.jpg
# output\L0000007\coin_0.jpg
# output\L0000007\coin_1.jpg
# output\L0000007\coin_2.jpg
# output\L0000007\coin_3.jpg
# output\L0000007\coin_4.jpg
# output\L0000007\coin_5.jpg
# output\L0000007\coin_6.jpg
# output\L0000007\coin_7.jpg
# output\L0000007\coin_8.jpg
# output\L0000007\coin_9.jpg
# output\L0000008\coin_0.jpg
# output\L0000008\coin_1.jpg
# output\L0000008\coin_2.jpg
# output\L0000008\coin_3.jpg
# output\L0000009\coin_0.jpg
# output\L0000009\coin_1.jpg
# output\L0000009\coin_2.jpg
# output\L0000010\coin_0.jpg
# output\L0000010\coin_1.jpg
# output\L0000010\coin_2.jpg
# output\L0000010\coin_3.jpg
# output\L0000010\coin_4.jpg
# output\L0000010\coin_5.jpg
# output\L0000010\coin_6.jpg
# output\L0000011\coin_0.jpg
# output\L0000011\coin_1.jpg
# output\L0000011\coin_2.jpg
# output\L0000011\coin_3.jpg
# output\L0000011\coin_4.jpg
# output\L0000011\coin_5.jpg
# output\L0000011\coin_6.jpg
# output\L0000011\coin_7.jpg
# output\L0000012\coin_0.jpg
# output\L0000012\coin_1.jpg
# output\L0000012\coin_2.jpg
# output\L0000012\coin_3.jpg
# output\L0000012\coin_4.jpg
# output\L0000012\coin_5.jpg
# output\L0000012\coin_6.jpg
# output\L0000013\coin_0.jpg
# output\L0000013\coin_1.jpg
# output\L0000013\coin_2.jpg
# output\L0000013\coin_3.jpg
# output\L0000013\coin_4.jpg
# output\L0000013\coin_5.jpg
# output\L0000013\coin_6.jpg
# output\L0000014\coin_0.jpg
# output\L0000014\coin_1.jpg
# output\L0000014\coin_2.jpg
# output\L0000014\coin_3.jpg
# output\L0000014\coin_4.jpg
# output\L0000014\coin_5.jpg
# output\L0000015\coin_0.jpg
# output\L0000015\coin_1.jpg
# output\L0000016\coin_0.jpg
# output\L0000016\coin_1.jpg
# output\L0000016\coin_2.jpg
# output\L0000016\coin_3.jpg
# output\L0000016\coin_4.jpg
# output\L0000016\coin_5.jpg
# output\L0000016\coin_6.jpg
# output\L0000016\coin_7.jpg
# output\L0000016\coin_8.jpg
# output\L0000017\coin_0.jpg
# output\L0000017\coin_1.jpg
# output\L0000017\coin_2.jpg
# output\L0000017\coin_3.jpg
# output\L0000017\coin_4.jpg
# output\L0000017\coin_5.jpg
# output\L0000017\coin_6.jpg
# output\L0000018\coin_0.jpg
# output\L0000018\coin_1.jpg
# output\L0000018\coin_2.jpg
# output\L0000018\coin_3.jpg
# output\L0000018\coin_4.jpg
# output\L0000018\coin_5.jpg
# output\L0000018\coin_6.jpg
# output\L0000019\coin_0.jpg
# output\L0000019\coin_1.jpg
# output\L0000019\coin_2.jpg
# output\L0000019\coin_3.jpg
# output\L0000019\coin_4.jpg
# output\L0000020\coin_0.jpg
# output\L0000020\coin_1.jpg
# output\L0000020\coin_2.jpg
# output\L0000020\coin_3.jpg
# output\L0000020\coin_4.jpg
# output\L0000020\coin_5.jpg
# output\L0000020\coin_6.jpg
# output\L0000020\coin_7.jpg
# output\L0000021\coin_0.jpg
# output\L0000021\coin_1.jpg
# output\L0000022\coin_0.jpg
# output\L0000022\coin_1.jpg
# output\L0000022\coin_2.jpg
# output\L0000022\coin_3.jpg
# output\L0000022\coin_4.jpg
# output\L0000022\coin_5.jpg
# output\L0000022\coin_6.jpg
# output\L0000022\coin_7.jpg
# output\L0000024\coin_0.jpg
# output\L0000024\coin_1.jpg
# output\L0000024\coin_2.jpg
# output\L0000024\coin_3.jpg
# output\L0000024\coin_4.jpg
# output\L0000024\coin_5.jpg
# output\L0000024\coin_6.jpg
# output\L0000025\coin_0.jpg
# output\L0000025\coin_1.jpg
# output\L0000025\coin_2.jpg
# output\L0000025\coin_3.jpg
# output\L0000026\coin_0.jpg
# output\L0000026\coin_1.jpg
# output\L0000026\coin_2.jpg
# output\L0000026\coin_3.jpg
# output\L0000026\coin_4.jpg
# output\L0000026\coin_5.jpg
# output\L0000026\coin_6.jpg
# output\L0000026\coin_7.jpg
# output\L0000027\coin_0.jpg
# output\L0000027\coin_1.jpg
# output\L0000027\coin_2.jpg
# output\L0000027\coin_3.jpg
# output\L0000027\coin_4.jpg
# output\L0000027\coin_5.jpg
# output\L0000027\coin_6.jpg
# output\L0000027\coin_7.jpg
# output\L0000027\coin_8.jpg
# output\L0000028\coin_0.jpg
# output\L0000028\coin_1.jpg
# output\L0000029\coin_0.jpg
# output\L0000029\coin_1.jpg
# output\L0000029\coin_2.jpg
# output\L0000029\coin_3.jpg
# output\L0000029\coin_4.jpg
# output\L0000030\coin_0.jpg
# output\L0000030\coin_1.jpg
# output\L0000030\coin_2.jpg
# output\L0000030\coin_3.jpg
# output\L0000030\coin_4.jpg
# output\L0000030\coin_5.jpg
# output\L0000030\coin_6.jpg
# output\L0000030\coin_7.jpg
# output\L0000030\coin_8.jpg
# output\L0000030\coin_9.jpg
# output\L0000031\coin_0.jpg
# output\L0000031\coin_1.jpg
# output\L0000031\coin_2.jpg
# output\L0000031\coin_3.jpg
# output\L0000032\coin_0.jpg
# output\L0000032\coin_1.jpg
# output\L0000032\coin_2.jpg
# output\L0000033\coin_0.jpg
# output\L0000033\coin_1.jpg
# output\L0000033\coin_10.jpg
# output\L0000033\coin_11.jpg
# output\L0000033\coin_12.jpg
# output\L0000033\coin_13.jpg
# output\L0000033\coin_2.jpg
# output\L0000033\coin_3.jpg
# output\L0000033\coin_4.jpg
# output\L0000033\coin_5.jpg
# output\L0000033\coin_6.jpg
# output\L0000033\coin_7.jpg
# output\L0000033\coin_8.jpg
# output\L0000033\coin_9.jpg
# output\L0000034\coin_0.jpg
# output\L0000034\coin_1.jpg
# output\L0000034\coin_2.jpg
# output\L0000034\coin_3.jpg
# output\L0000034\coin_4.jpg
# output\L0000035\coin_0.jpg
# output\L0000035\coin_1.jpg
# output\L0000035\coin_2.jpg
# output\L0000035\coin_3.jpg
# output\L0000035\coin_4.jpg
# output\L0000036\coin_0.jpg
# output\L0000037\coin_0.jpg
# output\L0000037\coin_1.jpg
# output\L0000037\coin_2.jpg
# output\L0000037\coin_3.jpg
# output\L0000037\coin_4.jpg
# output\L0000037\coin_5.jpg
# output\L0000037\coin_6.jpg
# output\L0000037\coin_7.jpg
# output\L0000037\coin_8.jpg
# output\L0000038\coin_0.jpg
# output\L0000038\coin_1.jpg
# output\L0000038\coin_2.jpg
# output\L0000038\coin_3.jpg
# output\L0000039\coin_0.jpg
# output\L0000039\coin_1.jpg
# output\L0000039\coin_2.jpg
# output\L0000040\coin_0.jpg
# output\L0000040\coin_1.jpg
# output\L0000040\coin_2.jpg
# output\L0000040\coin_3.jpg
# output\L0000041\coin_0.jpg
# output\L0000041\coin_1.jpg
# output\L0000041\coin_2.jpg
# output\L0000041\coin_3.jpg
# output\L0000041\coin_4.jpg
# output\L0000041\coin_5.jpg
# output\L0000041\coin_6.jpg
# output\L0000041\coin_7.jpg
# output\L0000042\coin_0.jpg
# output\L0000042\coin_1.jpg
# output\L0000042\coin_2.jpg
# output\L0000042\coin_3.jpg
# output\L0000042\coin_4.jpg
# output\L0000042\coin_5.jpg
# output\L0000042\coin_6.jpg
# output\L0000043\coin_0.jpg
# output\L0000043\coin_1.jpg
# output\L0000043\coin_2.jpg
# output\L0000043\coin_3.jpg
# output\L0000043\coin_4.jpg
# output\L0000043\coin_5.jpg
# output\L0000044\coin_0.jpg
# output\L0000044\coin_1.jpg
# output\L0000044\coin_2.jpg
# output\L0000044\coin_3.jpg
# output\L0000044\coin_4.jpg
# output\L0000044\coin_5.jpg
# output\L0000044\coin_6.jpg
# output\L0000045\coin_0.jpg
# output\L0000045\coin_1.jpg
# output\L0000045\coin_2.jpg
# output\L0000045\coin_3.jpg
# output\L0000045\coin_4.jpg
# output\L0000045\coin_5.jpg
# output\L0000045\coin_6.jpg
# output\L0000045\coin_7.jpg
# output\L0000045\coin_8.jpg
# output\L0000046\coin_0.jpg
# output\L0000046\coin_1.jpg
# output\L0000046\coin_2.jpg
# output\L0000046\coin_3.jpg
# output\L0000046\coin_4.jpg
# output\L0000047\coin_0.jpg
# output\L0000047\coin_1.jpg
# output\L0000047\coin_2.jpg
# output\L0000048\coin_0.jpg
# output\L0000049\coin_0.jpg
# output\L0000049\coin_1.jpg
# output\L0000049\coin_2.jpg
# output\L0000049\coin_3.jpg
# output\L0000049\coin_4.jpg
# output\L0000049\coin_5.jpg
# output\L0000049\coin_6.jpg
# output\L0000050\coin_0.jpg
# output\L0000050\coin_1.jpg
# output\L0000050\coin_2.jpg
# output\L0000050\coin_3.jpg
# output\L0000051\coin_0.jpg
# output\L0000051\coin_1.jpg
# output\L0000051\coin_2.jpg
# output\L0000051\coin_3.jpg
# output\L0000051\coin_4.jpg
# output\L0000051\coin_5.jpg
# output\L0000051\coin_6.jpg
# output\L0000051\coin_7.jpg
# output\L0000052\coin_0.jpg
# output\L0000052\coin_1.jpg
# output\L0000052\coin_2.jpg
# output\L0000052\coin_3.jpg
# output\L0000052\coin_4.jpg
# output\L0000053\coin_0.jpg
# output\L0000053\coin_1.jpg
# output\L0000053\coin_2.jpg
# output\L0000053\coin_3.jpg
# output\L0000053\coin_4.jpg
# output\L0000053\coin_5.jpg
# output\L0000053\coin_6.jpg
# output\L0000053\coin_7.jpg
# output\L0000054\coin_0.jpg
# output\L0000054\coin_1.jpg
# output\L0000054\coin_2.jpg
# output\L0000054\coin_3.jpg
# output\L0000054\coin_4.jpg
# output\L0000054\coin_5.jpg
# output\L0000054\coin_6.jpg
# output\L0000055\coin_0.jpg
# output\L0000055\coin_1.jpg
# output\L0000055\coin_2.jpg
# output\L0000055\coin_3.jpg
# output\L0000055\coin_4.jpg
# output\L0000055\coin_5.jpg
# output\L0000055\coin_6.jpg
# output\L0000056\coin_0.jpg
# output\L0000056\coin_1.jpg
# output\L0000056\coin_10.jpg
# output\L0000056\coin_2.jpg
# output\L0000056\coin_3.jpg
# output\L0000056\coin_4.jpg
# output\L0000056\coin_5.jpg
# output\L0000056\coin_6.jpg
# output\L0000056\coin_7.jpg
# output\L0000056\coin_8.jpg
# output\L0000056\coin_9.jpg
# output\L0000057\coin_0.jpg
# output\L0000057\coin_1.jpg
# output\L0000057\coin_2.jpg
# output\L0000057\coin_3.jpg
# output\L0000057\coin_4.jpg
# output\L0000057\coin_5.jpg
# output\L0000057\coin_6.jpg
# output\L0000058\coin_0.jpg
# output\L0000058\coin_1.jpg
# output\L0000058\coin_2.jpg
# output\L0000058\coin_3.jpg
# output\L0000059\coin_0.jpg
# output\L0000059\coin_1.jpg
# output\L0000059\coin_10.jpg
# output\L0000059\coin_11.jpg
# output\L0000059\coin_12.jpg
# output\L0000059\coin_13.jpg
# output\L0000059\coin_14.jpg
# output\L0000059\coin_2.jpg
# output\L0000059\coin_3.jpg
# output\L0000059\coin_4.jpg
# output\L0000059\coin_5.jpg
# output\L0000059\coin_6.jpg
# output\L0000059\coin_7.jpg
# output\L0000059\coin_8.jpg
# output\L0000059\coin_9.jpg
# output\L0000060\coin_0.jpg
# output\L0000060\coin_1.jpg
# output\L0000060\coin_10.jpg
# output\L0000060\coin_2.jpg
# output\L0000060\coin_3.jpg
# output\L0000060\coin_4.jpg
# output\L0000060\coin_5.jpg
# output\L0000060\coin_6.jpg
# output\L0000060\coin_7.jpg
# output\L0000060\coin_8.jpg
# output\L0000060\coin_9.jpg
# output\L0000061\coin_0.jpg
# output\L0000061\coin_1.jpg
# output\L0000061\coin_2.jpg
# output\L0000061\coin_3.jpg
# output\L0000061\coin_4.jpg
# output\L0000061\coin_5.jpg
# output\L0000061\coin_6.jpg
# output\L0000062\coin_0.jpg
# output\L0000062\coin_1.jpg
# output\L0000062\coin_2.jpg
# output\L0000062\coin_3.jpg
# output\L0000062\coin_4.jpg
# output\L0000062\coin_5.jpg
# output\L0000062\coin_6.jpg
# output\L0000062\coin_7.jpg
# output\L0000063\coin_0.jpg
# output\L0000063\coin_1.jpg
# output\L0000063\coin_2.jpg
# output\L0000063\coin_3.jpg
# output\L0000063\coin_4.jpg
# output\L0000063\coin_5.jpg
# output\L0000063\coin_6.jpg
# output\L0000064\coin_0.jpg
# output\L0000064\coin_1.jpg
# output\L0000064\coin_2.jpg
# output\L0000064\coin_3.jpg
# output\L0000064\coin_4.jpg
# output\L0000064\coin_5.jpg
# output\L0000064\coin_6.jpg
# output\L0000064\coin_7.jpg
# output\L0000064\coin_8.jpg
# output\L0000065\coin_0.jpg
# output\L0000065\coin_1.jpg
# output\L0000065\coin_2.jpg
# output\L0000065\coin_3.jpg
# output\L0000065\coin_4.jpg
# output\L0000065\coin_5.jpg
# output\L0000065\coin_6.jpg
# output\L0000065\coin_7.jpg
# output\L0000066\coin_0.jpg
# output\L0000066\coin_1.jpg
# output\L0000066\coin_2.jpg
# output\L0000066\coin_3.jpg
# output\L0000066\coin_4.jpg
# output\L0000066\coin_5.jpg
# output\L0000066\coin_6.jpg
# output\L0000067\coin_0.jpg
# output\L0000067\coin_1.jpg
# output\L0000067\coin_2.jpg
# output\L0000068\coin_0.jpg
# output\L0000068\coin_1.jpg
# output\L0000068\coin_2.jpg
# output\L0000068\coin_3.jpg
# output\L0000069\coin_0.jpg
# output\L0000069\coin_1.jpg
# output\L0000069\coin_10.jpg
# output\L0000069\coin_11.jpg
# output\L0000069\coin_12.jpg
# output\L0000069\coin_13.jpg
# output\L0000069\coin_14.jpg
# output\L0000069\coin_15.jpg
# output\L0000069\coin_16.jpg
# output\L0000069\coin_17.jpg
# output\L0000069\coin_2.jpg
# output\L0000069\coin_3.jpg
# output\L0000069\coin_4.jpg
# output\L0000069\coin_5.jpg
# output\L0000069\coin_6.jpg
# output\L0000069\coin_7.jpg
# output\L0000069\coin_8.jpg
# output\L0000069\coin_9.jpg
# output\L0000070\coin_0.jpg
# output\L0000070\coin_1.jpg
# output\L0000070\coin_2.jpg
# output\L0000071\coin_0.jpg
# output\L0000071\coin_1.jpg
# output\L0000071\coin_10.jpg
# output\L0000071\coin_11.jpg
# output\L0000071\coin_2.jpg
# output\L0000071\coin_3.jpg
# output\L0000071\coin_4.jpg
# output\L0000071\coin_5.jpg
# output\L0000071\coin_6.jpg
# output\L0000071\coin_7.jpg
# output\L0000071\coin_8.jpg
# output\L0000071\coin_9.jpg
# output\L0000072\coin_0.jpg
# output\L0000072\coin_1.jpg
# output\L0000072\coin_2.jpg
# output\L0000073\coin_0.jpg
# output\L0000073\coin_1.jpg
# output\L0000073\coin_2.jpg
# output\L0000073\coin_3.jpg
# output\L0000073\coin_4.jpg
# output\L0000073\coin_5.jpg
# output\L0000073\coin_6.jpg
# output\L0000073\coin_7.jpg
# output\L0000074\coin_0.jpg
# output\L0000074\coin_1.jpg
# output\L0000074\coin_2.jpg
# output\L0000074\coin_3.jpg
# output\L0000074\coin_4.jpg
# output\L0000074\coin_5.jpg
# output\L0000074\coin_6.jpg
# output\L0000074\coin_7.jpg
# output\L0000075\coin_0.jpg
# output\L0000075\coin_1.jpg
# output\L0000075\coin_2.jpg
# output\L0000075\coin_3.jpg
# output\L0000075\coin_4.jpg
# output\L0000075\coin_5.jpg
# output\L0000076\coin_0.jpg
# output\L0000076\coin_1.jpg
# output\L0000076\coin_2.jpg
# output\L0000076\coin_3.jpg
# output\L0000076\coin_4.jpg
# output\L0000076\coin_5.jpg
# output\L0000077\coin_0.jpg
# output\L0000077\coin_1.jpg
# output\L0000077\coin_2.jpg
# output\L0000077\coin_3.jpg
# output\L0000077\coin_4.jpg
# output\L0000077\coin_5.jpg
# output\L0000077\coin_6.jpg
# output\L0000078\coin_0.jpg
# output\L0000078\coin_1.jpg
# output\L0000078\coin_2.jpg
# output\L0000078\coin_3.jpg
# output\L0000078\coin_4.jpg
# output\L0000078\coin_5.jpg
# output\L0000078\coin_6.jpg
# output\L0000079\coin_0.jpg
# output\L0000079\coin_1.jpg
# output\L0000079\coin_2.jpg
# output\L0000079\coin_3.jpg
# output\L0000080\coin_0.jpg
# output\L0000080\coin_1.jpg
# output\L0000080\coin_2.jpg
# output\L0000080\coin_3.jpg
# output\L0000080\coin_4.jpg
# output\L0000081\coin_0.jpg
# output\L0000081\coin_1.jpg
# output\L0000082\coin_0.jpg
# output\L0000082\coin_1.jpg
# output\L0000082\coin_2.jpg
# output\L0000082\coin_3.jpg
# output\L0000083\coin_0.jpg
# output\L0000083\coin_1.jpg
# output\L0000083\coin_2.jpg
# output\L0000083\coin_3.jpg
# output\L0000083\coin_4.jpg
# output\L0000083\coin_5.jpg
# output\L0000083\coin_6.jpg
# output\L0000083\coin_7.jpg
# output\L0000083\coin_8.jpg
# output\L0000083\coin_9.jpg
# output\L0000084\coin_0.jpg
# output\L0000084\coin_1.jpg
# output\L0000084\coin_2.jpg
# output\L0000084\coin_3.jpg
# output\L0000084\coin_4.jpg
# output\L0000084\coin_5.jpg
# output\L0000085\coin_0.jpg
# output\L0000085\coin_1.jpg
# output\L0000085\coin_2.jpg
# output\L0000085\coin_3.jpg
# output\L0000085\coin_4.jpg
# output\L0000085\coin_5.jpg
# output\L0000085\coin_6.jpg
# output\L0000085\coin_7.jpg
# output\L0000086\coin_0.jpg
# output\L0000086\coin_1.jpg
# output\L0000086\coin_10.jpg
# output\L0000086\coin_11.jpg
# output\L0000086\coin_2.jpg
# output\L0000086\coin_3.jpg
# output\L0000086\coin_4.jpg
# output\L0000086\coin_5.jpg
# output\L0000086\coin_6.jpg
# output\L0000086\coin_7.jpg
# output\L0000086\coin_8.jpg
# output\L0000086\coin_9.jpg
# output\L0000087\coin_0.jpg
# output\L0000087\coin_1.jpg
# output\L0000087\coin_2.jpg
# output\L0000088\coin_0.jpg
# output\L0000089\coin_0.jpg
# output\L0000089\coin_1.jpg
# output\L0000089\coin_2.jpg
# output\L0000089\coin_3.jpg
# output\L0000089\coin_4.jpg
# output\L0000090\coin_0.jpg
# output\L0000090\coin_1.jpg
# output\L0000090\coin_2.jpg
# output\L0000090\coin_3.jpg
# output\L0000090\coin_4.jpg
# output\L0000090\coin_5.jpg
# output\L0000090\coin_6.jpg
# output\L0000091\coin_0.jpg
# output\L0000091\coin_1.jpg
# output\L0000091\coin_2.jpg
# output\L0000091\coin_3.jpg
# output\L0000091\coin_4.jpg
# output\L0000092\coin_0.jpg
# output\L0000092\coin_1.jpg
# output\L0000092\coin_2.jpg
# output\L0000092\coin_3.jpg
# output\L0000092\coin_4.jpg
# output\L0000092\coin_5.jpg
# output\L0000092\coin_6.jpg
# output\L0000093\coin_0.jpg
# output\L0000093\coin_1.jpg
# output\L0000093\coin_2.jpg
# output\L0000093\coin_3.jpg
# output\L0000093\coin_4.jpg
# output\L0000093\coin_5.jpg
# output\L0000093\coin_6.jpg
# output\L0000094\coin_0.jpg
# output\L0000095\coin_0.jpg
# output\L0000095\coin_1.jpg
# output\L0000095\coin_10.jpg
# output\L0000095\coin_2.jpg
# output\L0000095\coin_3.jpg
# output\L0000095\coin_4.jpg
# output\L0000095\coin_5.jpg
# output\L0000095\coin_6.jpg
# output\L0000095\coin_7.jpg
# output\L0000095\coin_8.jpg
# output\L0000095\coin_9.jpg
# output\L0000096\coin_0.jpg
# output\L0000096\coin_1.jpg
# output\L0000096\coin_2.jpg
# output\L0000096\coin_3.jpg
# output\L0000096\coin_4.jpg
# output\L0000096\coin_5.jpg
# output\L0000096\coin_6.jpg
# output\L0000097\coin_0.jpg
# output\L0000097\coin_1.jpg
# output\L0000097\coin_2.jpg
# output\L0000097\coin_3.jpg
# output\L0000097\coin_4.jpg
# output\L0000097\coin_5.jpg
# output\L0000097\coin_6.jpg
# output\L0000098\coin_0.jpg
# output\L0000098\coin_1.jpg
# output\L0000098\coin_2.jpg
# output\L0000098\coin_3.jpg
# output\L0000098\coin_4.jpg
# output\L0000098\coin_5.jpg
# output\L0000098\coin_6.jpg
# output\L0000098\coin_7.jpg
# output\L0000098\coin_8.jpg
# output\L0000099\coin_0.jpg
# output\L0000099\coin_1.jpg
# output\L0000099\coin_2.jpg
# output\L0000099\coin_3.jpg
# output\L0000099\coin_4.jpg
# output\L0000099\coin_5.jpg
# output\L0000099\coin_6.jpg
# output\L0000100\coin_0.jpg
# output\L0000100\coin_1.jpg
# output\L0000100\coin_10.jpg
# output\L0000100\coin_11.jpg
# output\L0000100\coin_12.jpg
# output\L0000100\coin_13.jpg
# output\L0000100\coin_14.jpg
# output\L0000100\coin_15.jpg
# output\L0000100\coin_16.jpg
# output\L0000100\coin_17.jpg
# output\L0000100\coin_18.jpg
# output\L0000100\coin_2.jpg
# output\L0000100\coin_3.jpg
# output\L0000100\coin_4.jpg
# output\L0000100\coin_5.jpg
# output\L0000100\coin_6.jpg
# output\L0000100\coin_7.jpg
# output\L0000100\coin_8.jpg
# output\L0000100\coin_9.jpg
# output\L0000101\coin_0.jpg
# output\L0000101\coin_1.jpg
# output\L0000101\coin_10.jpg
# output\L0000101\coin_2.jpg
# output\L0000101\coin_3.jpg
# output\L0000101\coin_4.jpg
# output\L0000101\coin_5.jpg
# output\L0000101\coin_6.jpg
# output\L0000101\coin_7.jpg
# output\L0000101\coin_8.jpg
# output\L0000101\coin_9.jpg
# output\L0000102\coin_0.jpg
# output\L0000102\coin_1.jpg
# output\L0000102\coin_2.jpg
# output\L0000103\coin_0.jpg
# output\L0000103\coin_1.jpg
# output\L0000104\coin_0.jpg
# output\L0000104\coin_1.jpg
# output\L0000104\coin_2.jpg
# output\L0000104\coin_3.jpg
# output\L0000104\coin_4.jpg
# output\L0000104\coin_5.jpg
# output\L0000104\coin_6.jpg
# output\L0000104\coin_7.jpg
# output\L0000105\coin_0.jpg
# output\L0000105\coin_1.jpg
# output\L0000105\coin_2.jpg
# output\L0000105\coin_3.jpg
# output\L0000105\coin_4.jpg
# output\L0000105\coin_5.jpg
# output\L0000106\coin_0.jpg
# output\L0000106\coin_1.jpg
# output\L0000106\coin_2.jpg
# output\L0000106\coin_3.jpg
# output\L0000106\coin_4.jpg
# output\L0000106\coin_5.jpg
# output\L0000106\coin_6.jpg
# output\L0000106\coin_7.jpg
# output\L0000107\coin_0.jpg
# output\L0000107\coin_1.jpg
# output\L0000107\coin_2.jpg
# output\L0000107\coin_3.jpg
# output\L0000107\coin_4.jpg
# output\L0000108\coin_0.jpg
# output\L0000108\coin_1.jpg
# output\L0000108\coin_2.jpg
# output\L0000109\coin_0.jpg
# output\L0000109\coin_1.jpg
# output\L0000109\coin_2.jpg
# output\L0000109\coin_3.jpg
# output\L0000109\coin_4.jpg
# output\L0000109\coin_5.jpg
# output\L0000109\coin_6.jpg
# output\L0000109\coin_7.jpg
# output\L0000109\coin_8.jpg
# output\L0000110\coin_0.jpg
# output\L0000110\coin_1.jpg
# output\L0000110\coin_2.jpg
# output\L0000110\coin_3.jpg
# output\L0000110\coin_4.jpg
# output\L0000110\coin_5.jpg
# output\L0000111\coin_0.jpg
# output\L0000111\coin_1.jpg
# output\L0000111\coin_2.jpg
# output\L0000111\coin_3.jpg
# output\L0000111\coin_4.jpg
# output\L0000111\coin_5.jpg
# output\L0000111\coin_6.jpg
# output\L0000112\coin_0.jpg
# output\L0000112\coin_1.jpg
# output\L0000112\coin_10.jpg
# output\L0000112\coin_2.jpg
# output\L0000112\coin_3.jpg
# output\L0000112\coin_4.jpg
# output\L0000112\coin_5.jpg
# output\L0000112\coin_6.jpg
# output\L0000112\coin_7.jpg
# output\L0000112\coin_8.jpg
# output\L0000112\coin_9.jpg
# output\L0000113\coin_0.jpg
# output\L0000113\coin_1.jpg
# output\L0000113\coin_2.jpg
# output\L0000113\coin_3.jpg
# output\L0000113\coin_4.jpg
# output\L0000114\coin_0.jpg
# output\L0000114\coin_1.jpg
# output\L0000114\coin_2.jpg
# output\L0000114\coin_3.jpg
# output\L0000115\coin_0.jpg
# output\L0000115\coin_1.jpg
# output\L0000115\coin_2.jpg
# output\L0000115\coin_3.jpg
# output\L0000115\coin_4.jpg
# output\L0000116\coin_0.jpg
# output\L0000116\coin_1.jpg
# output\L0000116\coin_2.jpg
# output\L0000116\coin_3.jpg
# output\L0000116\coin_4.jpg
# output\L0000116\coin_5.jpg
# output\L0000116\coin_6.jpg
# output\L0000116\coin_7.jpg
# output\L0000117\coin_0.jpg
# output\L0000118\coin_0.jpg
# output\L0000118\coin_1.jpg
# output\L0000118\coin_10.jpg
# output\L0000118\coin_11.jpg
# output\L0000118\coin_12.jpg
# output\L0000118\coin_13.jpg
# output\L0000118\coin_14.jpg
# output\L0000118\coin_2.jpg
# output\L0000118\coin_3.jpg
# output\L0000118\coin_4.jpg
# output\L0000118\coin_5.jpg
# output\L0000118\coin_6.jpg
# output\L0000118\coin_7.jpg
# output\L0000118\coin_8.jpg
# output\L0000118\coin_9.jpg
# output\L0000119\coin_0.jpg
# output\L0000119\coin_1.jpg
# output\L0000119\coin_2.jpg
# output\L0000119\coin_3.jpg
# output\L0000119\coin_4.jpg
# output\L0000119\coin_5.jpg
# output\L0000119\coin_6.jpg
# output\L0000120\coin_0.jpg
# output\L0000120\coin_1.jpg
# output\L0000120\coin_2.jpg
# output\L0000120\coin_3.jpg
# output\L0000120\coin_4.jpg
# output\L0000120\coin_5.jpg
# output\L0000121\coin_0.jpg
# output\L0000121\coin_1.jpg
# output\L0000121\coin_2.jpg
# output\L0000121\coin_3.jpg
# output\L0000121\coin_4.jpg
# output\L0000121\coin_5.jpg
# output\L0000122\coin_0.jpg
# output\L0000122\coin_1.jpg
# output\L0000122\coin_2.jpg
# output\L0000122\coin_3.jpg
# output\L0000122\coin_4.jpg
# output\L0000122\coin_5.jpg
# output\L0000122\coin_6.jpg
# output\L0000122\coin_7.jpg
# output\L0000123\coin_0.jpg
# output\L0000123\coin_1.jpg
# output\L0000123\coin_2.jpg
# output\L0000123\coin_3.jpg
# output\L0000123\coin_4.jpg
# output\L0000123\coin_5.jpg
# output\L0000123\coin_6.jpg
# output\L0000123\coin_7.jpg
# output\L0000123\coin_8.jpg
# output\L0000124\coin_0.jpg
# output\L0000124\coin_1.jpg
# output\L0000124\coin_2.jpg
# output\L0000124\coin_3.jpg
# output\L0000124\coin_4.jpg
# output\L0000124\coin_5.jpg
# output\L0000124\coin_6.jpg
# output\L0000124\coin_7.jpg
# output\L0000124\coin_8.jpg
# output\L0000125\coin_0.jpg
# output\L0000125\coin_1.jpg
# output\L0000125\coin_2.jpg
# output\L0000125\coin_3.jpg
# output\L0000125\coin_4.jpg
# output\L0000125\coin_5.jpg
# output\L0000125\coin_6.jpg
# output\L0000126\coin_0.jpg
# output\L0000126\coin_1.jpg
# output\L0000126\coin_2.jpg
# output\L0000126\coin_3.jpg
# output\L0000126\coin_4.jpg
# output\L0000127\coin_0.jpg
# output\L0000127\coin_1.jpg
# output\L0000127\coin_2.jpg
# output\L0000128\coin_0.jpg
# output\L0000128\coin_1.jpg
# output\L0000128\coin_2.jpg
# output\L0000128\coin_3.jpg
# output\L0000128\coin_4.jpg
# output\L0000129\coin_0.jpg
# output\L0000129\coin_1.jpg
# output\L0000129\coin_2.jpg
# output\L0000129\coin_3.jpg
# output\L0000129\coin_4.jpg
# output\L0000130\coin_0.jpg
# output\L0000130\coin_1.jpg
# output\L0000130\coin_2.jpg
# output\L0000130\coin_3.jpg
# output\L0000130\coin_4.jpg
# output\L0000130\coin_5.jpg
# output\L0000130\coin_6.jpg
# output\L0000130\coin_7.jpg
# output\L0000131\coin_0.jpg
# output\L0000131\coin_1.jpg
# output\L0000131\coin_2.jpg
# output\L0000131\coin_3.jpg
# output\L0000131\coin_4.jpg
# output\L0000131\coin_5.jpg
# output\L0000131\coin_6.jpg
# output\L0000131\coin_7.jpg
# output\L0000131\coin_8.jpg
# output\L0000132\coin_0.jpg
# output\L0000133\coin_0.jpg
# output\L0000133\coin_1.jpg
# output\L0000133\coin_2.jpg
# output\L0000134\coin_0.jpg
# output\L0000134\coin_1.jpg
# output\L0000134\coin_2.jpg
# output\L0000134\coin_3.jpg
# output\L0000134\coin_4.jpg
# output\L0000134\coin_5.jpg
# output\L0000135\coin_0.jpg
# output\L0000135\coin_1.jpg
# output\L0000135\coin_2.jpg
# output\L0000135\coin_3.jpg
# output\L0000135\coin_4.jpg
# output\L0000135\coin_5.jpg
# output\L0000135\coin_6.jpg
# output\L0000136\coin_0.jpg
# output\L0000136\coin_1.jpg
# output\L0000137\coin_0.jpg
# output\L0000137\coin_1.jpg
# output\L0000137\coin_2.jpg
# output\L0000137\coin_3.jpg
# output\L0000137\coin_4.jpg
# output\L0000137\coin_5.jpg
# output\L0000137\coin_6.jpg
# output\L0000137\coin_7.jpg
# output\L0000137\coin_8.jpg
# output\L0000137\coin_9.jpg
# output\L0000138\coin_0.jpg
# output\L0000138\coin_1.jpg
# output\L0000138\coin_2.jpg
# output\L0000138\coin_3.jpg
# output\L0000138\coin_4.jpg
# output\L0000138\coin_5.jpg
# output\L0000138\coin_6.jpg
# output\L0000138\coin_7.jpg
# output\L0000138\coin_8.jpg
# output\L0000138\coin_9.jpg
# output\L0000139\coin_0.jpg
# output\L0000139\coin_1.jpg
# output\L0000139\coin_2.jpg
# output\L0000139\coin_3.jpg
# output\L0000139\coin_4.jpg
# output\L0000139\coin_5.jpg
# output\L0000139\coin_6.jpg
# output\L0000139\coin_7.jpg
# output\L0000140\coin_0.jpg
# output\L0000140\coin_1.jpg
# output\L0000140\coin_2.jpg
# output\L0000141\coin_0.jpg
# output\L0000141\coin_1.jpg
# output\L0000141\coin_2.jpg
# output\L0000141\coin_3.jpg
# output\L0000141\coin_4.jpg
# output\L0000141\coin_5.jpg
# output\L0000141\coin_6.jpg
# output\L0000142\coin_0.jpg
# output\L0000142\coin_1.jpg
# output\L0000143\coin_0.jpg
# output\L0000143\coin_1.jpg
# output\L0000143\coin_2.jpg
# output\L0000143\coin_3.jpg
# output\L0000143\coin_4.jpg
# output\L0000143\coin_5.jpg
# output\L0000143\coin_6.jpg
# output\L0000144\coin_0.jpg
# output\L0000144\coin_1.jpg
# output\L0000144\coin_2.jpg
# output\L0000144\coin_3.jpg
# output\L0000144\coin_4.jpg
# output\L0000144\coin_5.jpg
# output\L0000144\coin_6.jpg
# output\L0000144\coin_7.jpg
# output\L0000144\coin_8.jpg
# output\L0000145\coin_0.jpg
# output\L0000145\coin_1.jpg
# output\L0000145\coin_10.jpg
# output\L0000145\coin_11.jpg
# output\L0000145\coin_2.jpg
# output\L0000145\coin_3.jpg
# output\L0000145\coin_4.jpg
# output\L0000145\coin_5.jpg
# output\L0000145\coin_6.jpg
# output\L0000145\coin_7.jpg
# output\L0000145\coin_8.jpg
# output\L0000145\coin_9.jpg
# output\L0000146\coin_0.jpg
# output\L0000146\coin_1.jpg
# output\L0000146\coin_2.jpg
# output\L0000146\coin_3.jpg
# output\L0000146\coin_4.jpg
# output\L0000146\coin_5.jpg
# output\L0000147\coin_0.jpg
# output\L0000147\coin_1.jpg
# output\L0000147\coin_2.jpg
# output\L0000147\coin_3.jpg
# output\L0000147\coin_4.jpg
# output\L0000147\coin_5.jpg
# output\L0000147\coin_6.jpg
# output\L0000147\coin_7.jpg
# output\L0000147\coin_8.jpg
# output\L0000147\coin_9.jpg
# output\L0000148\coin_0.jpg
# output\L0000148\coin_1.jpg
# output\L0000148\coin_2.jpg
# output\L0000148\coin_3.jpg
# output\L0000148\coin_4.jpg
# output\L0000148\coin_5.jpg
# output\L0000149\coin_0.jpg
# output\L0000149\coin_1.jpg
# output\L0000149\coin_2.jpg
# output\L0000149\coin_3.jpg
# output\L0000149\coin_4.jpg
# output\L0000149\coin_5.jpg
# output\L0000149\coin_6.jpg
# output\L0000149\coin_7.jpg
# output\L0000150\coin_0.jpg
# output\L0000150\coin_1.jpg
# output\L0000150\coin_2.jpg
# output\L0000150\coin_3.jpg
# output\L0000150\coin_4.jpg
# output\L0000150\coin_5.jpg
# output\L0000150\coin_6.jpg
# output\L0000151\coin_0.jpg
# output\L0000151\coin_1.jpg
# output\L0000151\coin_2.jpg
# output\L0000151\coin_3.jpg
# output\L0000151\coin_4.jpg
# output\L0000151\coin_5.jpg
# output\L0000151\coin_6.jpg
# output\L0000151\coin_7.jpg
# output\L0000151\coin_8.jpg
# output\L0000152\coin_0.jpg
# output\L0000152\coin_1.jpg
# output\L0000152\coin_2.jpg
# output\L0000152\coin_3.jpg
# output\L0000153\coin_0.jpg
# output\L0000153\coin_1.jpg
# output\L0000153\coin_2.jpg
# output\L0000153\coin_3.jpg
# output\L0000153\coin_4.jpg
# output\L0000153\coin_5.jpg
# output\L0000154\coin_0.jpg
# output\L0000154\coin_1.jpg
# output\L0000155\coin_0.jpg
# output\L0000155\coin_1.jpg
# output\L0000155\coin_2.jpg
# output\L0000156\coin_0.jpg
# output\L0000156\coin_1.jpg
# output\L0000156\coin_2.jpg
# output\L0000156\coin_3.jpg
# output\L0000156\coin_4.jpg
# output\L0000156\coin_5.jpg
# output\L0000157\coin_0.jpg
# output\L0000157\coin_1.jpg
# output\L0000157\coin_2.jpg
# output\L0000157\coin_3.jpg
# output\L0000157\coin_4.jpg
# output\L0000157\coin_5.jpg
# output\L0000157\coin_6.jpg
# output\L0000158\coin_0.jpg
# output\L0000158\coin_1.jpg
# output\L0000158\coin_2.jpg
# output\L0000158\coin_3.jpg
# output\L0000158\coin_4.jpg
# output\L0000158\coin_5.jpg
# output\L0000158\coin_6.jpg
# output\L0000158\coin_7.jpg
# output\L0000159\coin_0.jpg
# output\L0000159\coin_1.jpg
# output\L0000159\coin_2.jpg
# output\L0000160\coin_0.jpg
# output\L0000160\coin_1.jpg
# output\L0000160\coin_2.jpg
# output\L0000160\coin_3.jpg
# output\L0000160\coin_4.jpg
# output\L0000160\coin_5.jpg
# output\L0000160\coin_6.jpg
# output\L0000160\coin_7.jpg
# output\L0000160\coin_8.jpg
# output\L0000161\coin_0.jpg
# output\L0000161\coin_1.jpg
# output\L0000161\coin_2.jpg
# output\L0000161\coin_3.jpg
# output\L0000161\coin_4.jpg
# output\L0000161\coin_5.jpg
# output\L0000161\coin_6.jpg
# output\L0000161\coin_7.jpg
# output\L0000161\coin_8.jpg
# output\L0000161\coin_9.jpg

# %% [markdown]
# ## Confustion matrix on validation set

# %%
import pandas as pd
import seaborn as sns

Y_pred = model.predict(val_generator, 1167//32+1)
y_pred = np.argmax(Y_pred, axis=1)
cfm = confusion_matrix(val_generator.classes, y_pred)
cfm = np.around(cfm.astype('float')/cfm.sum(axis=1)[:, np.newaxis], decimals=2)
classes = ['0.1CHF', '0.1EUR', '0.01EUR', '0.2CHF', '0.2EUR', '0.02EUR', '0.5CHF', '0.05CHF', '0.5EUR', '0.05EUR', '1CHF', '1EUR', '2CHF', '2EUR', '5CHF', 'OOD']
cfm_pd = pd.DataFrame(cfm, index = classes, columns = classes)
figure = plt.figure(figsize=(8,8))
sns.heatmap(cfm_pd, annot=True, cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step
